# %% [markdown]
# # Outline
#
# ```
# 1. grep all the species in each time interval
#
# the working_data.csv file lists all the species in Ursidae and separate them number of occurrences, identifiable name, and the time interval
#
# cut -d ',' -f 4 working_data.csv |sort | uniq > time_period.txt
# uniq time intervals are appended into a separate file
#
# Make a timeline, listing the time periods in order (oldest to most current) -> require citation
#
#
#
# 2. put them on separate dictionaries by time interval
#
# refer back to the working function 2 ipython notebook
# group occurences of unique species in a given time interval
#
# def makebearDict(filename):
#     bearDict = {}
#     fobj = open(filename, "r", encoding = "ISO-8859-15")
#     all_records = fobj.readlines()[1:]
#     for line in all_records:
#         record_elements = line.split(",")
#         interval = record_elements[0]
#         species = record_elements[1]
#         bearDict[interval] = species
#     return bearDict
#
# bear = makebearDict("working_data.csv")
# species = list(bear.keys())
# species.sort()
# bear
#
#
# 3. Use Rstudio to graph number of occurences of unique species in a given timeline. Then show them side by side
#
# ```

# %%
from IPython.display import Image
Image(filename='reference_1.png')

# %%
from IPython.display import Image
Image(filename='reference_2.png')
